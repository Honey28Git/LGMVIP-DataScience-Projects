# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras 
from tensorflow.keras.preprocessing.text import Tokenizer
from nltk.tokenize import RegexpTokenizer
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Activation, Embedding, Dropout
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import pickle
import heapq
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
path = '1661-0.txt'
with open(path,'r', encoding = 'utf-8') as file:
    text = file.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 581888

# %%
# Preprocessing
text = text.lower()  # Convert to lowercase
words = text.split()  # Tokenization

# %%
# Unique words and frequency count
unique_words = set(words)
word_freq = {word: words.count(word) for word in unique_words}

print("Unique Words:", unique_words)
# Out:
# Unique Words: {'clergyman,', 'beyond', 'foresight', 'silence,', '1.e.7', 'ak', 'bruise,', 'two-storied,', 'warranties', 'mercy!”', 'cocktail', 'twitching', 'cabinet?”', 'lestrade,', 'daylight', 'within.', 'twenty', 'middle', 'damp,', 'earnestly', 'stream', '‘we’ve', 'wednesday', '“read', '“peculiar—that', 'grove', 'allowance', 'before!', 'chap', 'something!', 'grow', '“still,', 'tap', 'neighbouring', 'establishment,', 'major', 'fringed', 'failed.”', 'apply,', 'bedtime', 'reasons,”', 'ink', 'disagreeable', 'unobserved.', 'brassy', 'opinion,”', 'standing', 'amply', 'taxes.', '“evidently,”', 'stiff,', 'old,', 'research', 'punctures', 'rucastles', 'ring.”', 'fenchurch', 'six', 'typewritten,”', 'refer', '“tell', 'minutes’', 'distinction', 'consult,”', 'send', 'named.', 'founder', 'hushing', 'lateness', 'catastrophe.', 'of.', '“where’s', 'frayed', 'wee', 'office?', 'spring,', 'doctor', 'box,', 'soul,', 'research.', 'culprit.', 'sleep?’', 'nor', 'shots.', '“unless', 'still', 'them', 'dozen.”', 'feathers,', 'letters,”', 'swayed', 'direction,', '“it—it’s', 'hot.”', 'construction', 'necessity', 'copies', 'roof', 'laughing.', 'hands,', 'o’clock,', 'providing', 'french', 'vacant', 'arrested.”', '($1', 'felony,', 'country.', 'prices', 'days,', 'madly,', '1.a.', 'waited', '“eight', 'strip,', 'codes', '“perfectly', 'kind-hearted.', 'lame.”', 'lawyer,', 'discuss', 'animated.', 'red-heads', 'mailing', '‘hullo!’', 'crippled', 'side', 'height;', 'which.', 'cleared', 'cut,', 'hot-headed', 'introspect.', 'trouble!”', 'nest', 'blotting-paper,', 'burst', 'whispering', 'hardihood', 'fall', 'fields.', 'tattered', 'thief?', 'completely', 'not,”', 'tricks', 'unseat', 'under,', 'water,', 'dressing-gown,', 'need.”', 'enters', 'observant,', 'dad?”', 'dozen', 'sedentary', 'express', 'admirably', 'factor', 'ill-usage', 'offices', 'all', 'covered', 'police-station', 'hat,', 'success.”', 'peterson', 'conscience.', 'snapped,', 'frank;', 'unofficial', 'away.”', 'died,', 'chain', 'wait,', 'posted', 'vigil?', 'mad!', 'chance;', '“‘look', 'air', 'bundle', 'stall,', 'government', 'process', 'this.', 'lichen-blotched', 'missing,’', 'intend', 'term', 'filed', 'battered', 'according', 'yes!', 'viii.', 'eagerly,', '‘death', 'aunt,', 'capable', '"defects,"', 'insight', 'gravity', 'saddles', '30,000;', 'unnecessary.', 'visitor', 'point.”', 'predominates', '‘co.’', 'sticks,', 'side-whiskered,', 'formed', 'mcfarlane’s', 'cheer', 'humming', 'dwell', 'jovial', 'personate', 'apparent', '_chronicle_,”', 'completely.', 'north,”', 'sit.', 'breakfast-room.”', 'abnormal,', 'help?’', 'half-column', 'mystery,', 'journeyed', 'morcar’s', '“here’s', 'idea.', 'millions', 'product,', 'mystery?”', 'marks.”', 'home', 'fritz!’', 'ball', 'returned.', 'roughly', 'acting', 'deny', 'south-west,', 'names.', 'acts', 'gullet', 'without', 'bridegroom', 'runs', 'agreement,', '“‘next', 'disclaimers', 'evenings', 'thumped', 'agreement.', 'amusing', 'travellers.', 'affair?', 'fringe', 'finish', 'beast.', 'provision', 'breaking', 'forever.', 'suggestive', 'fully', 'painful', 'edition.', 'shivering.”', 'writing?’', 'useful.’', '“‘in', 'legal', 'local', 'sidled', 'glossy.”', 'anything,', 'movement', 'nervous,', 'quiet!”', 'figure.', 'securing', '_evening', 'arrived.', 'silent!', 'enemy?”', 'ear.', 'adventure', 'unlikely', '“do', 'late!”', 'write', 'slope,', 'together!”', 'ring-finger,', 'silver', 'breakfast,', 'european', 'way,’', 'afternoon,”', 'cluster', 'parched', 'wimpole', 'river.”', 'horses,', 'gently.', 'seedy', 'birchmoor,', 'serious', 'agitated.', 'hand-made', 'grimesby', 'room?”', 'lightened', 'pockets,', 'hundred', 'half-hopeful', 'sides,', 'importance,', 'wink', '29,', 'nocturnal', 'maid-servants', 'gravely', 'invent', 'lee.', 'includes', 'employs', 'effect,”', 'barque', 'obey', 'wonderfully', 'good.', '1869', 'balustraded', 'robber.', 'eyebrows.', 'escapade', 'gong', 'tissue', 'disputatious', 'inconvenience', 'winter.', 'swain', 'bolted.', 'wickedness', 'unclaspings', 'klan.', 'mark', 'clearly ...
# Word Frequencies: {'clergyman,': 1, 'beyond': 10, 'foresight': 3, 'silence,': 7, '1.e.7': 2, 'ak': 1, 'bruise,': 1, 'two-storied,': 1, 'warranties': 3, 'mercy!”': 2, 'cocktail': 1, 'twitching': 1, 'cabinet?”': 1, 'lestrade,': 8, 'daylight': 1, 'within.': 1, 'twenty': 11, 'middle': 8, 'damp,': 1, 'earnestly': 3, 'stream': 4, '‘we’ve': 1, 'wednesday': 2, '“read': 1, '“peculiar—that': 1, 'grove': 1, 'allowance': 1, 'before!': 1, 'chap': 2, 'something!': 1, 'grow': 2, '“still,': 3, 'tap': 2, 'neighbouring': 3, 'establishment,': 1, 'major': 4, 'fringed': 1, 'failed.”': 1, 'apply,': 1, 'bedtime': 1, 'reasons,”': 1, 'ink': 2, 'disagreeable': 2, 'unobserved.': 1, 'brassy': 1, 'opinion,”': 1, 'standing': 21, 'amply': 1, 'taxes.': 1, '“evidently,”': 1, 'stiff,': 1, 'old,': 2, 'research': 2, 'punctures': 1, 'rucastles': 4, 'ring.”': 2, 'fenchurch': 2, 'six': 21, 'typewritten,”': 1, 'refer': 1, '“tell': 1, 'minutes’': 1, 'distinction': 1, 'consult,”': 1, 'send': 14, 'named.': 1, 'founder': 1, 'hushing': 1, 'lateness': 1, 'catastrophe.': 1, 'of.': 2, '“where’s': 1, 'frayed': 1, 'wee': 1, 'office?': 1, 'spring,': 1, 'doctor': 10, 'box,': 1, 'soul,': 1, 'research.': 1, 'culprit.': 1, 'sleep?’': 1, 'nor': 16, 'shots.': 1, '“unless': 1, 'still': 61, 'them': 84, 'dozen.”': 2, 'feathers,': 1, 'letters,”': 1, 'swayed': 1, 'direction,': 2, '“it—it’s': 1, 'hot.”': 1, 'construction': 1, 'necessity': 1, 'copies': 7, 'roof': 4, 'laughing.': 9, 'hands,': 6, 'o’clock,': 6, 'providing': 5, 'french': 3, 'vacant': 1, 'arrested.”': 1, '($1': 1, 'felony,': 1, 'country.': 6, 'prices': 1, 'days,': 3, 'madly,': 1, '1.a.': 1, 'waited': 13, '“eight': 1, 'strip,': 1, 'codes': 1, '“perfectly': 1, 'kind-hearted.': 1, 'lame.”': 1, 'lawyer,': 1, 'discuss': 5, 'animated.': 1, 'red-heads': 1, 'mailing': 1, '‘hullo!’': 1, 'crippled': 1, 'side': 52, 'height;': 1, 'which.': 1, 'cleared': 12, 'cut,': 1, 'hot-headed': 1, 'introspect.': 1, 'trouble!”': 1, 'nest': 1, 'blotting-paper,': 1, 'burst': 7, 'whispering': 1, 'hardihood': 1, 'fall': 9, 'fields.': 3, 'tattered': 2, 'thief?': 1, 'completely': 1, 'not,”': 1, 'tricks': 1, 'unseat': 1, 'under,': 1, 'water,': 4, 'dressing-gown,': 5, 'need.”': 1, 'enters': 1, 'observant,': 1, 'dad?”': 1, 'dozen': 8, 'sedentary': 1, 'express': 1, 'admirably': 3, 'factor': 3, 'ill-usage': 1, 'offices': 4, 'all': 339, 'covered': 9, 'police-station': 1, 'hat,': 12, 'success.”': 1, 'peterson': 3, 'conscience.': 1, 'snapped,': 1, 'frank;': 1, 'unofficial': 1, 'away.”': 3, 'died,': 2, 'chain': 4, 'wait,': 2, 'posted': 7, 'vigil?': 1, 'mad!': 1, 'chance;': 1, '“‘look': 2, 'air': 17, 'bundle': 5, 'stall,': 1, 'government': 2, 'process': 3, 'this.': 6, 'lichen-blotched': 1, 'missing,’': 1, 'intend': 1, 'term': 1, 'filed': 1, 'battered': 3, 'according': 2, 'yes!': 2, 'viii.': 2, 'eagerly,': 1, '‘death': 1, 'aunt,': 1, 'capable': 5, '"defects,"': 1, 'insight': 3, 'gravity': 2, 'saddles': 1, '30,000;': 1, 'unnecessary.': 1, 'visitor': 14, 'point.”': 3, 'predominates': 1, '‘co.’': 1, 'sticks,': 1, 'side-whiskered,': 1, 'formed': 10, 'mcfarlane’s': 1, 'cheer': 1, 'humming': 2, 'dwell': 1, 'jovial': 2, 'personate': 1, 'apparent': 1, '_chronicle_,”': 1, 'completely.': 4, 'north,”': 1, 'sit.': 1, 'breakfast-room.”': 1, 'abnormal,': 1, 'help?’': 1, 'half-column': 1, 'mystery,': 1, 'journeyed': 1, 'morcar’s': 1, '“here’s': 1, 'idea.': 3, 'millions': 1, 'product,': 1, 'mystery?”': 1, 'marks.”': 1, 'home': 34, 'fritz!’': 1, 'ball': 2, 'returned.': 3, 'roughly': 2, 'acting': 3, 'deny': 1, 'south-west,': 1, 'names.': 1, 'acts': 1, 'gullet': 1, 'without': 80, 'bridegroom': 4, 'runs': 5, 'agreement,': 6, '“‘next': 1, 'disclaimers': 1, 'evenings': 1, 'thumped': 1, 'agreement.': 3, 'amusing': 1, 'travellers.': 1, 'affair?': 1, 'fringe': 4, 'finish': 1, 'beast.': 1, 'provision': 2, 'breaking': 8, 'forever.': 4, 'suggestive': 4, 'fully': 4, 'painful': 7, 'edition.': 1, 'shivering.”': 1, 'writing?’': 1, 'useful.’': 1, '“‘in': 2, 'legal': 5, 'local': 5, 'sidled': 1, 'glossy ...

# %%
print("Word Frequencies:", word_freq)
# Out:
# Word Frequencies: {'clergyman,': 1, 'beyond': 10, 'foresight': 3, 'silence,': 7, '1.e.7': 2, 'ak': 1, 'bruise,': 1, 'two-storied,': 1, 'warranties': 3, 'mercy!”': 2, 'cocktail': 1, 'twitching': 1, 'cabinet?”': 1, 'lestrade,': 8, 'daylight': 1, 'within.': 1, 'twenty': 11, 'middle': 8, 'damp,': 1, 'earnestly': 3, 'stream': 4, '‘we’ve': 1, 'wednesday': 2, '“read': 1, '“peculiar—that': 1, 'grove': 1, 'allowance': 1, 'before!': 1, 'chap': 2, 'something!': 1, 'grow': 2, '“still,': 3, 'tap': 2, 'neighbouring': 3, 'establishment,': 1, 'major': 4, 'fringed': 1, 'failed.”': 1, 'apply,': 1, 'bedtime': 1, 'reasons,”': 1, 'ink': 2, 'disagreeable': 2, 'unobserved.': 1, 'brassy': 1, 'opinion,”': 1, 'standing': 21, 'amply': 1, 'taxes.': 1, '“evidently,”': 1, 'stiff,': 1, 'old,': 2, 'research': 2, 'punctures': 1, 'rucastles': 4, 'ring.”': 2, 'fenchurch': 2, 'six': 21, 'typewritten,”': 1, 'refer': 1, '“tell': 1, 'minutes’': 1, 'distinction': 1, 'consult,”': 1, 'send': 14, 'named.': 1, 'founder': 1, 'hushing': 1, 'lateness': 1, 'catastrophe.': 1, 'of.': 2, '“where’s': 1, 'frayed': 1, 'wee': 1, 'office?': 1, 'spring,': 1, 'doctor': 10, 'box,': 1, 'soul,': 1, 'research.': 1, 'culprit.': 1, 'sleep?’': 1, 'nor': 16, 'shots.': 1, '“unless': 1, 'still': 61, 'them': 84, 'dozen.”': 2, 'feathers,': 1, 'letters,”': 1, 'swayed': 1, 'direction,': 2, '“it—it’s': 1, 'hot.”': 1, 'construction': 1, 'necessity': 1, 'copies': 7, 'roof': 4, 'laughing.': 9, 'hands,': 6, 'o’clock,': 6, 'providing': 5, 'french': 3, 'vacant': 1, 'arrested.”': 1, '($1': 1, 'felony,': 1, 'country.': 6, 'prices': 1, 'days,': 3, 'madly,': 1, '1.a.': 1, 'waited': 13, '“eight': 1, 'strip,': 1, 'codes': 1, '“perfectly': 1, 'kind-hearted.': 1, 'lame.”': 1, 'lawyer,': 1, 'discuss': 5, 'animated.': 1, 'red-heads': 1, 'mailing': 1, '‘hullo!’': 1, 'crippled': 1, 'side': 52, 'height;': 1, 'which.': 1, 'cleared': 12, 'cut,': 1, 'hot-headed': 1, 'introspect.': 1, 'trouble!”': 1, 'nest': 1, 'blotting-paper,': 1, 'burst': 7, 'whispering': 1, 'hardihood': 1, 'fall': 9, 'fields.': 3, 'tattered': 2, 'thief?': 1, 'completely': 1, 'not,”': 1, 'tricks': 1, 'unseat': 1, 'under,': 1, 'water,': 4, 'dressing-gown,': 5, 'need.”': 1, 'enters': 1, 'observant,': 1, 'dad?”': 1, 'dozen': 8, 'sedentary': 1, 'express': 1, 'admirably': 3, 'factor': 3, 'ill-usage': 1, 'offices': 4, 'all': 339, 'covered': 9, 'police-station': 1, 'hat,': 12, 'success.”': 1, 'peterson': 3, 'conscience.': 1, 'snapped,': 1, 'frank;': 1, 'unofficial': 1, 'away.”': 3, 'died,': 2, 'chain': 4, 'wait,': 2, 'posted': 7, 'vigil?': 1, 'mad!': 1, 'chance;': 1, '“‘look': 2, 'air': 17, 'bundle': 5, 'stall,': 1, 'government': 2, 'process': 3, 'this.': 6, 'lichen-blotched': 1, 'missing,’': 1, 'intend': 1, 'term': 1, 'filed': 1, 'battered': 3, 'according': 2, 'yes!': 2, 'viii.': 2, 'eagerly,': 1, '‘death': 1, 'aunt,': 1, 'capable': 5, '"defects,"': 1, 'insight': 3, 'gravity': 2, 'saddles': 1, '30,000;': 1, 'unnecessary.': 1, 'visitor': 14, 'point.”': 3, 'predominates': 1, '‘co.’': 1, 'sticks,': 1, 'side-whiskered,': 1, 'formed': 10, 'mcfarlane’s': 1, 'cheer': 1, 'humming': 2, 'dwell': 1, 'jovial': 2, 'personate': 1, 'apparent': 1, '_chronicle_,”': 1, 'completely.': 4, 'north,”': 1, 'sit.': 1, 'breakfast-room.”': 1, 'abnormal,': 1, 'help?’': 1, 'half-column': 1, 'mystery,': 1, 'journeyed': 1, 'morcar’s': 1, '“here’s': 1, 'idea.': 3, 'millions': 1, 'product,': 1, 'mystery?”': 1, 'marks.”': 1, 'home': 34, 'fritz!’': 1, 'ball': 2, 'returned.': 3, 'roughly': 2, 'acting': 3, 'deny': 1, 'south-west,': 1, 'names.': 1, 'acts': 1, 'gullet': 1, 'without': 80, 'bridegroom': 4, 'runs': 5, 'agreement,': 6, '“‘next': 1, 'disclaimers': 1, 'evenings': 1, 'thumped': 1, 'agreement.': 3, 'amusing': 1, 'travellers.': 1, 'affair?': 1, 'fringe': 4, 'finish': 1, 'beast.': 1, 'provision': 2, 'breaking': 8, 'forever.': 4, 'suggestive': 4, 'fully': 4, 'painful': 7, 'edition.': 1, 'shivering.”': 1, 'writing?’': 1, 'useful.’': 1, '“‘in': 2, 'legal': 5, 'local': 5, 'sidled': 1, 'glossy ...

# %%
# Prepare sequences
input_sequences = []
output_words = []

for i in range(len(words) - sequence_length):
    input_sequences.append(words[i:i + sequence_length])
    output_words.append(words[i + sequence_length])  # Ensure this corresponds to the input

# Encode the sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(input_sequences)
total_words = len(tokenizer.word_index) + 1

input_sequences = tokenizer.texts_to_sequences(input_sequences)

# Convert output_words to sequences
output_words = tokenizer.texts_to_sequences(output_words)

# Flatten output_words
output_words = [word[0] for word in output_words if len(word) > 0]

# Convert to arrays
input_sequences = pad_sequences(input_sequences, maxlen=sequence_length)
input_sequences = np.array(input_sequences)
output_words = np.array(output_words)

# Make sure they are of the same length
min_length = min(len(input_sequences), len(output_words))
input_sequences = input_sequences[:min_length]
output_words = output_words[:min_length]

# Check lengths
print("Input Sequences Shape:", input_sequences.shape)
print("Output Words Shape:", output_words.shape)
# Out:
# Input Sequences Shape: (105131, 5)
# Output Words Shape: (105131,)

# %%
# Build the model
model = Sequential()
model.add(Embedding(total_words, 100, input_length=sequence_length))
model.add(LSTM(150, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(150))
model.add(Dropout(0.2))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
model.fit(input_sequences, output_words, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 65s 40ms/step - accuracy: 0.5056 - loss: 2.3095
# Epoch 2/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 64s 39ms/step - accuracy: 0.5192 - loss: 2.2404
# Epoch 3/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 64s 39ms/step - accuracy: 0.5261 - loss: 2.1885
# Epoch 4/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 65s 39ms/step - accuracy: 0.5375 - loss: 2.1339
# Epoch 5/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 66s 40ms/step - accuracy: 0.5450 - loss: 2.0941
# Epoch 6/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 66s 40ms/step - accuracy: 0.5521 - loss: 2.0456
# Epoch 7/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 65s 40ms/step - accuracy: 0.5621 - loss: 2.0012
# Epoch 8/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 65s 40ms/step - accuracy: 0.5664 - loss: 1.9668
# Epoch 9/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 65s 40ms/step - accuracy: 0.5758 - loss: 1.9198
# Epoch 10/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 66s 40ms/step - accuracy: 0.5801 - loss: 1.8956
# Epoch 11/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 68s 41ms/step - accuracy: 0.5886 - loss: 1.8501
# Epoch 12/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 66s 40ms/step - accuracy: 0.5943 - loss: 1.8115
# Epoch 13/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 84s 41ms/step - accuracy: 0.6005 - loss: 1.7869
# Epoch 14/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 68s 41ms/step - accuracy: 0.6068 - loss: 1.7408
# Epoch 15/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - accuracy: 0.6128 - loss: 1.7157
# Epoch 16/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 66s 40ms/step - accuracy: 0.6150 - loss: 1.6934
# Epoch 17/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 83s 41ms/step - accuracy: 0.6256 - loss: 1.6654
# Epoch 18/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 66s 40ms/step - accuracy: 0.6265 - loss: 1.6454
# Epoch 19/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - accuracy: 0.6323 - loss: 1.6053
# Epoch 20/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 69s 42ms/step - accuracy: 0.6371 - loss: 1.5912
# Epoch 21/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 68s 42ms/step - accuracy: 0.6433 - loss: 1.5523
# Epoch 22/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 68s 41ms/step - accuracy: 0.6434 - loss: 1.5440
# Epoch 23/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - accuracy: 0.6504 - loss: 1.5174
# Epoch 24/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 69s 42ms/step - accuracy: 0.6553 - loss: 1.4889
# Epoch 25/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 69s 42ms/step - accuracy: 0.6569 - loss: 1.4831
# Epoch 26/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 67s 41ms/step - accuracy: 0.6611 - loss: 1.4545
# Epoch 27/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 70s 43ms/step - accuracy: 0.6637 - loss: 1.4341
# Epoch 28/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 68s 41ms/step - accuracy: 0.6683 - loss: 1.4202
# Epoch 29/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 69s 42ms/step - accuracy: 0.6690 - loss: 1.3981
# Epoch 30/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 68s 42ms/step - accuracy: 0.6806 - loss: 1.3653
# Epoch 31/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 70s 43ms/step - accuracy: 0.6799 - loss: 1.3551
# Epoch 32/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 69s 42ms/step - accuracy: 0.6794 - loss: 1.3507
# Epoch 33/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 69s 42ms/step - accuracy: 0.6816 - loss: 1.3450
# Epoch 34/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 71s 43ms/step - accuracy: 0.6860 - loss: 1.3237
# Epoch 35/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 71s 43ms/step - accuracy: 0.6884 - loss: 1.3050
# Epoch 36/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 71s 43ms/step - accuracy: 0.6917 - loss: 1.2930
# Epoch 37/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 70s 43ms/step - accuracy: 0.6987 - loss: 1.2679
# Epoch 38/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 70s 43ms/step - accuracy: 0.6988 - loss: 1.2571
# Epoch 39/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 71s 43ms/step - accuracy: 0.7040 - loss: 1.2408
# Epoch 40/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 71s 43ms/step - accuracy: 0.7056 - loss: 1.2252
# Epoch 41/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - accuracy: 0.7065 - loss: 1.2235
# Epoch 42/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 71s 43ms/step - accuracy: 0.7121 - loss: 1.1961
# Epoch 43/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 71s 43ms/step - accuracy: 0.7129 - loss: 1.1918
# Epoch 44/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - accuracy: 0.7129 - loss: 1.1847
# Epoch 45/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - accuracy: 0.7157 - loss: 1.1727
# Epoch 46/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 72s 44ms/step - accuracy: 0.7180 - loss: 1.1617
# Epoch 47/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 73s 45ms/step - accuracy: 0.7230 - loss: 1.1454
# Epoch 48/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 73s 45ms/step - accuracy: 0.7236 - loss: 1.1377
# Epoch 49/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 73s 45ms/step - accuracy: 0.7247 - loss: 1.1222
# Epoch 50/50
# 1643/1643 ━━━━━━━━━━━━━━━━━━━━ 73s 44ms/step - accuracy: 0.7277 - loss: 1.1148

# %%
with open('1661-0.txt', 'r', encoding='utf-8') as f:
    text_data = f.read()
text_data = text_data.lower()  # Convert to lowercase
text_data = text_data.replace('\n', ' ')

# %%
tokenizer = Tokenizer(num_words=14556)  # Setting vocabulary size
tokenizer.fit_on_texts([text_data])

# %%
def sample(preds, top_n=3):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds + 1e-10)  # Adding a small constant to prevent log(0)
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    return heapq.nlargest(top_n, range(len(preds)), preds.take)

# %%
def predict_next_word(model, tokenizer, input_text, n=1):
    predicted_words = []
    for text in input_text:
        sequence = tokenizer.texts_to_sequences([text.lower()])[-1]  # Ensure it's a string
        sequence = pad_sequences([sequence], maxlen=sequence_length)  # Use your defined sequence length
        predicted_probs = model.predict(sequence, verbose=0)[0]
        next_indices = sample(predicted_probs, n)
        predicted_words.append([indices_char[idx] for idx in next_indices])  # Adjust for your character mapping
    return predicted_words

# %%
input_text = [
    "It is not a lack of love, but a lack of friendship that makes unhappy marriages.",
    "That which does not kill us makes us stronger.",
    "I'm not upset that you lied to me, I'm upset that from now on I can't believe you.",
    "And those who were seen dancing were thought to be insane by those who could not hear the music.",
    "It is hard enough to remember my opinions, without also remembering my reasons for them!"
]

predicted_words = predict_next_word(model, tokenizer, input_text, n=3)
for i, prediction in enumerate(predicted_words):
    print(f"Input: '{input_text[i]}'")
    print(f"Predicted next words: {prediction}")
    print()
# Out:
# Input: 'It is not a lack of love, but a lack of friendship that makes unhappy marriages.'
# Predicted next words: ['ready', 'afterwards', 'business']
#
# Input: 'That which does not kill us makes us stronger.'
# Predicted next words: ['might', 'who', 'all']
#
# Input: 'I'm not upset that you lied to me, I'm upset that from now on I can't believe you.'
# Predicted next words: ['at', 'when', 'for']
#
# Input: 'And those who were seen dancing were thought to be insane by those who could not hear the music.'
# Predicted next words: ['listened', 'whom', 'but']
#
# Input: 'It is hard enough to remember my opinions, without also remembering my reasons for them!'
# Predicted next words: ['there', 'but', 'through']
